# %% [markdown]
# <a href="https://colab.research.google.com/github/rodrigopcad/API-Watson-Assistant/blob/master/Trabalho_Final_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
import pandas as pd
from datetime import datetime
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
PATH = '/content/drive/MyDrive/Datasets/netflix_titles.csv'

# %%
def format_date(string): 
  dt = datetime.strptime(str(string), '%B %d, %Y')
  return dt.strftime('%Y-%m-%d')

# %%
df = df.replace(np.nan, '', regex=True)
df_obj = df.select_dtypes(['object'])
df[df_obj.columns] = df_obj.apply(lambda x: x.str.strip())
df['seasons'] = df['duration'].apply(lambda dur: int("".join(filter(str.isdigit, dur))) if 'season' in dur.lower() else 0)
df['minutes'] = df['duration'].apply(lambda dur: int("".join(filter(str.isdigit, dur))) if 'min' in dur.lower() else 0)
df['date_added_formatted'] = df['date_added'].apply(lambda date_added: format_date(date_added) if not date_added == '' else '')
df['cast_array'] = df['cast'].apply(lambda genre: genre.split(', '))
df['listed_in_array'] = df['listed_in'].apply(lambda genre: genre.split(', '))
df_movies = df[df['type']=='Movie']
df_shows = df[df['type']=='TV Show']

# %%
df_movies.head(1)
# Out:
#   show_id  ...                 listed_in_array
# 1      s2  ...  [Dramas, International Movies]
#
# [1 rows x 17 columns]

# %%
df_horror = df_movies[df_movies['listed_in_array'].apply(lambda x: 'Horror Movies' in x)]
df_horror = df_horror.groupby(['rating'])
df_horror.head()
# Out:
#      show_id  ...                                    listed_in_array
# 2         s3  ...              [Horror Movies, International Movies]
# 6         s7  ...              [Horror Movies, International Movies]
# 8         s9  ...              [Horror Movies, International Movies]
# 9        s10  ...   [Horror Movies, International Movies, Thrillers]
# 27       s28  ...   [Horror Movies, International Movies, Thrillers]
# 41       s42  ...              [Horror Movies, International Movies]
# 62       s63  ...     [Horror Movies, Independent Movies, Thrillers]
# 65       s66  ...                         [Horror Movies, Thrillers]
# 69       s70  ...                         [Horror Movies, Thrillers]
# 183     s184  ...                          [Comedies, Horror Movies]
# 184     s185  ...                [Horror Movies, Independent Movies]
# 275     s276  ...   [Horror Movies, International Movies, Thrillers]
# 315     s316  ...  [Horror Movies, Independent Movies, Internatio...
# ...
